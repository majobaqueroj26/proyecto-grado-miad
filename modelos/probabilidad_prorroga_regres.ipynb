# %%
# Importacion de librerias
# Conexión a la base de datos
# ==========================================
import os
import sys
import pathlib


sys.path.append(
    os.path.join(pathlib.Path(os.getcwd()).parent)
)


from utils.bq_conn import bq_conn_file

bq_client = bq_conn_file(project_id="dsa-miad-365616")

# Tratamiento de datos
# ==========================================
import pandas as pd
import numpy as np
from datetime import datetime

# Graficas
# ==========================================
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import seaborn as sns

# Modelos ML
# ==========================================
from sklearn import preprocessing
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from IPython.display import display

# %% [markdown]
# ## Importo data

# %%
pd.options.display.max_columns = None

query = '''
SELECT
    *
FROM `Proyecto.DatosSecopI`
ORDER BY anno_cargue_secop DESC
'''
bq_client = bq_conn_file(project_id="dsa-miad-365616")
secop_I = bq_client.execute_query(query=query)
print(f"El número de filas del dataset: {secop_I.shape[0]}\nEl número de columnas del dataset: {secop_I.shape[1]}")
secop_I.head(5)
# Out:
# El número de filas del dataset: 26553
# El número de columnas del dataset: 38
#                    uid  anno_cargue_secop  id_modalidad  \
# 0   191389136418143424               2019            13
# 1  1912101041779226352               2019            12
# 2  1912101443259265538               2019            12
# 3   191294985788644918               2019            12
# 4   191988590538059861               2019            19
#
#      modalidad_de_contratacion estado_del_proceso  id_objeto_a_contratar  \
# 0  contratacion minima cuantia          celebrado               50000000
# 1  contratacion directa ley de          celebrado               53000000
# 2  contratacion directa ley de          celebrado               55000000
# 3  contratacion directa ley de          liquidado               72000000
# 4   asociacion publico privada          celebrado               73000000
#
#                       detalle_del_objeto_a_contratar  \
# 0  contratar servicio suministro elementos materi...
# 1  adquisicion uniformes para dotar personal cuer...
# 2  contratar diseno produccion tarjetas presentac...
# 3  prestar servicio mantenimiento preventivo corr...
# 4  desintegracion vehiculos automotores estado in...
#
#                 tipo_de_contrato municipio_de_obtencion municipios_ejecucion_  \
# 0                     suministro             facatativa            facatativa
# 1        prestacion de servicios                 bogota                bogota
# 2        prestacion de servicios                 bogota                bogota
# 3        prestacion de servicios                 bogota                bogota
# 4  no encontrado en hoja proceso                 bogota                bogota
#
#   departamento_ejecucion                       numero_de_proceso  \
# 0           cundinamarca                    CPMMSFFAMCNo01DE2019
# 1                 bogota  DIRGENERALCONTRATACIONDIRECTA184DE2019
# 2                 bogota  DIRGENERALCONTRATACIONDIRECTA188DE2019
# 3                 bogota  DIRGENERALCONTRATACIONDIRECTA106DE2019
# 4                 bogota           CONVENIODEASOCIACIÓN231DE2018
#
#      numero_de_contrato  cuantia_proceso id_grupo            nombre_grupo  \
# 0  CPMMSFFAMCNO01DE2019         50000000        E  productos de uso final
# 1             184DE2019      22980096902        E  productos de uso final
# 2             188DE2019         35998452        E  productos de uso final
# 3             106DE2019         16767536        F               servicios
# 4             231DE2018                0        F               servicios
#
#   id_familia                                     nombre_familia id_clase  \
# 0       5022                    productos de cereales legumbres   502213
# 1       5310                                               ropa   531027
# 2       5510                                    medios impresos   551015
# 3       7210  servicios de mantenimiento reparaciones de con...   721015
# 4       7318                   servicios de maquinado procesado   731810
#
#                               nombre_clase id_adjudicacion  \
# 0              harina productos de molinos         8143424
# 1                                uniformes         9226352
# 2                   publicaciones impresas         9265538
# 3  servicios de apoyo para la construccion         8644918
# 4                   servicios de maquinado         8059861
#
#   tipo_identifi_del_contratista identificacion_del_contratista  \
# 0       nit de persona juridica                      900791326
# 1       nit de persona juridica                      860020227
# 2       nit de persona juridica                      830001113
# 3       nit de persona juridica                      860025639
# 4       nit de persona juridica                      806011019
#
#                nom_razon_social_contratista tipo_doc_representante_legal  \
# 0                         inversiones ocazo         cedula de ciudadania
# 1       fondo rotatorio de la policia forpo      nit de persona juridica
# 2             imprenta nacional de colombia      nit de persona juridica
# 3  mitsubishi electric de colombia limitada      nit de persona juridica
# 4      recuperaciones naranjo recycling sas         cedula de ciudadania
#
#   identific_representante_legal  plazo_de_ejec_del_contrato_  \
# 0                    1022363447                          330
# 1                     860020227                          660
# 2                     830001113                           31
# 3                     860025639                          170
# 4                      57439563                          360
#
#    dias_ejec_final_contrato rango_de_ejec_del_contrato  prorrogado  \
# 0                       330                          D           0
# 1                       690                          D           1
# 2                        71                          D           1
# 3                       170                          D           0
# 4                       360                          D           0
#
#    tiempo_adiciones_en_dias  cuantia_contrato  con_adicion_pptal  \
# 0                         0          50000000                  0
# 1                        30       22980096902                  0
# 2                        40          35998452                  0
# 3                         0          16767536                  0
# 4                         0                 0                  0
#
#    valor_total_de_adiciones  valor_contrato_con_adiciones           moneda  \
# 0                         0                      50000000  peso colombiano
# 1                         0                   22980096902  peso colombiano
# 2                         0                      35998452  peso colombiano
# 3                         0                      16767536  peso colombiano
# 4                         0                             0  peso colombiano
#
#                             objeto_del_contrato_a_la  \
# 0  contratar compra elementos materia prima para ...
# 1  adquisicion uniformes para dotar personal cuer...
# 2  contratar diseno produccion tarjetas presentac...
# 3  prestar servicio mantenimiento preventivo corr...
# 4  desintegracion vehiculos automotores estado in...
#
#                              ruta_proceso_en_secop_i
# 0  {'url': 'https://www.contratos.gov.co/consulta...
# 1  {'url': 'https://www.contratos.gov.co/consulta...
# 2  {'url': 'https://www.contratos.gov.co/consulta...
# 3  {'url': 'https://www.contratos.gov.co/consulta...
# 4  {'url': 'https://www.contratos.gov.co/consulta...

# %%
secopI_filter = secop_I.filter(items=['id_modalidad','estado_del_proceso','id_objeto_a_contratar','tipo_de_contrato',
                                      'departamento_ejecucion','cuantia_proceso','id_grupo',
                                      'id_familia','id_clase','prorrogado','plazo_de_ejec_del_contrato_'
                                      ])
secopI_filter.head(5)
# Out:
#    id_modalidad estado_del_proceso  id_objeto_a_contratar  \
# 0            13          celebrado               50000000
# 1            12          celebrado               53000000
# 2            12          celebrado               55000000
# 3            12          liquidado               72000000
# 4            19          celebrado               73000000
#
#                 tipo_de_contrato departamento_ejecucion  cuantia_proceso  \
# 0                     suministro           cundinamarca         50000000
# 1        prestacion de servicios                 bogota      22980096902
# 2        prestacion de servicios                 bogota         35998452
# 3        prestacion de servicios                 bogota         16767536
# 4  no encontrado en hoja proceso                 bogota                0
#
#   id_grupo id_familia id_clase  prorrogado  plazo_de_ejec_del_contrato_
# 0        E       5022   502213           0                          330
# 1        E       5310   531027           1                          660
# 2        E       5510   551015           1                           31
# 3        F       7210   721015           0                          170
# 4        F       7318   731810           0                          360

# %%
secopI_filter['estado_del_proceso'] = secopI_filter['estado_del_proceso'].astype('category')
secopI_filter['tipo_de_contrato'] = secopI_filter['tipo_de_contrato'].astype('category')
secopI_filter['departamento_ejecucion'] = secopI_filter['departamento_ejecucion'].astype('category')
secopI_filter['id_grupo'] = secopI_filter['id_grupo'].astype('category')
secopI_filter['id_familia'] = secopI_filter['id_familia'].astype('category')
secopI_filter['id_clase'] = secopI_filter['id_clase'].astype('category')
secopI_filter['plazo_de_ejec_del_contrato_'] = secopI_filter['plazo_de_ejec_del_contrato_'].astype('category')

# %% [markdown]
# ## Preprocesamiento - Pipeline y ColumnTransformer
#
#
# Las clases ColumnTransformer y make_column_transformer del módulo sklearn.compose permiten combinar múltiples transformaciones de preprocesado, especificando a qué columnas se aplica cada una. Como todo transformer, tiene un método de entrenamiento (fit) y otro de transformación (transform) . Esto permite que el aprendizaje de las transformaciones se haga únicamente con observaciones de entrenamiento, y se puedan aplicar después a cualquier conjunto de datos. La idea detrás de este módulo es la siguiente:
#
# Definir todas las transformaciones (escalado, selección, filtrado...) que se desea aplicar y a qué columnas ColumnTransformer(). La selección de columnas puede hacerse por: nombre. índice, máscara booleana, slice, patrón regex, por tipo de columna o con las funciones de selección make_column_selector.
#
# Aprender los parámetros necesarios para dichas transformaciones con las observaciones de entrenamiento .fit().
#
# Aplicar las transformaciones aprendidas a cualquier conjunto de datos .transform().

# %%
numeric_cols = secopI_filter.select_dtypes(include=['float64', 'int']).columns.to_list()
cat_cols = secopI_filter.select_dtypes(include=['object', 'category']).columns.to_list()

# Transformaciones para las variables numéricas
numeric_transformer = Pipeline(
                        steps=[
                            ('imputer', SimpleImputer(strategy='median')),
                            ('scaler', StandardScaler())
                        ]
                      )


# Transformaciones para las variables categóricas
categorical_transformer = Pipeline(
                            steps=[
                                ('imputer', SimpleImputer(strategy='most_frequent')),
                                ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
                            ]
                          )

preprocessor = ColumnTransformer(
                    transformers=[
                        ('numeric', numeric_transformer, numeric_cols),
                        ('cat', categorical_transformer, cat_cols)
                    ],
                    remainder='passthrough',
                    verbose_feature_names_out = False
               ).set_output(transform="pandas")

secopI_filter_prep = preprocessor.fit_transform(secopI_filter)

# %%
#secopI_filter_prep = pd.concat([secopI_filter_prep, y_prorroga], axis=1)
secopI_filter_prep['prorrogado'].value_counts()
# Out:
# -0.168135    25823
#  5.947602      730
# Name: prorrogado, dtype: int64

# %% [markdown]
# ### Conjunto de datos en *train* y *test*
#
# Se particiona el conjunto de datos dos subconjuntos de datos, *train* que es el conjunto de datos utilizados para entrenar los modelos el cual representa el 80% de los datos totales y *test* para comprobar el rendimiento de los modelos que representa el 20% restante.

# %%
# conjunto de datos train
train_datos = secopI_filter_prep.sample(frac=0.9, random_state=0)
# conjunto de datos test
test_datos = secopI_filter_prep.drop(train_datos.index)

# %%
train_datos.head(2)
# Out:
#        id_modalidad  id_objeto_a_contratar  cuantia_proceso  \
# 23698      0.276131              -0.034082        -0.103451
# 19086      0.276131               0.116789        -0.039885
#
#        estado_del_proceso_adjudicado  estado_del_proceso_borrador  \
# 23698                            0.0                          0.0
# 19086                            0.0                          0.0
#
#        estado_del_proceso_celebrado  estado_del_proceso_convocado  \
# 23698                           0.0                           1.0
# 19086                           0.0                           0.0
#
#        estado_del_proceso_descartado  estado_del_proceso_liquidado  \
# 23698                            0.0                           0.0
# 19086                            0.0                           1.0
#
#        estado_del_proceso_terminado sin liquidar  ...  \
# 23698                                        0.0  ...
# 19086                                        0.0  ...
#
#        plazo_de_ejec_del_contrato__1095  plazo_de_ejec_del_contrato__1170  \
# 23698                               0.0                               0.0
# 19086                               0.0                               0.0
#
#        plazo_de_ejec_del_contrato__1200  plazo_de_ejec_del_contrato__1800  \
# 23698                               0.0                               0.0
# 19086                               0.0                               0.0
#
#        plazo_de_ejec_del_contrato__2700  plazo_de_ejec_del_contrato__4980  \
# 23698                               0.0                               0.0
# 19086                               0.0                               0.0
#
#        plazo_de_ejec_del_contrato__5280  plazo_de_ejec_del_contrato__6690  \
# 23698                               0.0                               0.0
# 19086                               0.0                               0.0
#
#        plazo_de_ejec_del_contrato__7500  prorrogado
# 23698                               0.0           0
# 19086                               0.0           0
#
# [2 rows x 1692 columns]

# %% [markdown]
# ## Modelos Regresión

# %%
# import pycaret regression and init setup
from pycaret.regression import *
s = setup(train_datos, 
          target = 'prorrogado', 
          feature_selection=True, 
          fold=5, train_size= 0.8,
          preprocess=True,
          session_id = 123)
models()
# Out:
# <style type="text/css">
# #T_3c992_row8_col1, #T_3c992_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3c992">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c992_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3c992_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c992_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c992_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3c992_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3c992_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3c992_row1_col1" class="data row1 col1" >prorrogado</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3c992_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3c992_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3c992_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_3c992_row3_col1" class="data row3 col1" >(23898, 1692)</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3c992_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_3c992_row4_col1" class="data row4 col1" >(23898, 339)</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3c992_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_3c992_row5_col1" class="data row5 col1" >(19118, 339)</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3c992_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_3c992_row6_col1" class="data row6 col1" >(4780, 339)</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3c992_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_3c992_row7_col1" class="data row7 col1" >1691</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3c992_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_3c992_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3c992_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_3c992_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3c992_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_3c992_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3c992_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_3c992_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3c992_row12_col0" class="data row12 col0" >Feature selection</td>
#       <td id="T_3c992_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3c992_row13_col0" class="data row13 col0" >Feature selection method</td>
#       <td id="T_3c992_row13_col1" class="data row13 col1" >classic</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3c992_row14_col0" class="data row14 col0" >Feature selection estimator</td>
#       <td id="T_3c992_row14_col1" class="data row14 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3c992_row15_col0" class="data row15 col0" >Number of features selected</td>
#       <td id="T_3c992_row15_col1" class="data row15 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3c992_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_3c992_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3c992_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_3c992_row17_col1" class="data row17 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3c992_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_3c992_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3c992_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_3c992_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3c992_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_3c992_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3c992_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_3c992_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3c992_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3c992_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_3c992_row22_col1" class="data row22 col1" >6fb4</td>
#     </tr>
#   </tbody>
# </table>
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# xgboost           Extreme Gradient Boosting
# lightgbm    Light Gradient Boosting Machine
# catboost                 CatBoost Regressor
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr              sklearn.linear_model._base.LinearRegression   True
# lasso        sklearn.linear_model._coordinate_descent.Lasso   True
# ridge                     sklearn.linear_model._ridge.Ridge   True
# en        sklearn.linear_model._coordinate_descent.Elast...   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                sklearn.svm._classes.SVR  False
# knn       sklearn.neighbors._regression.KNeighborsRegressor   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf           sklearn.ensemble._forest.RandomForestRegressor   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# xgboost                        xgboost.sklearn.XGBRegressor   True
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# catboost                    catboost.core.CatBoostRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True

# %%
# compare models
best = compare_models()
# Out:
# <style type="text/css">
# #T_ba5c3 th {
#   text-align: left;
# }
# #T_ba5c3_row0_col0, #T_ba5c3_row0_col1, #T_ba5c3_row0_col6, #T_ba5c3_row1_col0, #T_ba5c3_row1_col1, #T_ba5c3_row1_col2, #T_ba5c3_row1_col3, #T_ba5c3_row1_col4, #T_ba5c3_row1_col6, #T_ba5c3_row2_col0, #T_ba5c3_row2_col1, #T_ba5c3_row2_col2, #T_ba5c3_row2_col3, #T_ba5c3_row2_col4, #T_ba5c3_row2_col5, #T_ba5c3_row2_col6, #T_ba5c3_row3_col0, #T_ba5c3_row3_col1, #T_ba5c3_row3_col2, #T_ba5c3_row3_col3, #T_ba5c3_row3_col4, #T_ba5c3_row3_col5, #T_ba5c3_row3_col6, #T_ba5c3_row4_col0, #T_ba5c3_row4_col1, #T_ba5c3_row4_col2, #T_ba5c3_row4_col3, #T_ba5c3_row4_col4, #T_ba5c3_row4_col5, #T_ba5c3_row4_col6, #T_ba5c3_row5_col0, #T_ba5c3_row5_col1, #T_ba5c3_row5_col2, #T_ba5c3_row5_col3, #T_ba5c3_row5_col4, #T_ba5c3_row5_col5, #T_ba5c3_row5_col6, #T_ba5c3_row6_col0, #T_ba5c3_row6_col1, #T_ba5c3_row6_col2, #T_ba5c3_row6_col3, #T_ba5c3_row6_col4, #T_ba5c3_row6_col5, #T_ba5c3_row6_col6, #T_ba5c3_row7_col0, #T_ba5c3_row7_col1, #T_ba5c3_row7_col2, #T_ba5c3_row7_col3, #T_ba5c3_row7_col4, #T_ba5c3_row7_col5, #T_ba5c3_row7_col6, #T_ba5c3_row8_col0, #T_ba5c3_row8_col1, #T_ba5c3_row8_col2, #T_ba5c3_row8_col3, #T_ba5c3_row8_col4, #T_ba5c3_row8_col5, #T_ba5c3_row8_col6, #T_ba5c3_row9_col0, #T_ba5c3_row9_col1, #T_ba5c3_row9_col2, #T_ba5c3_row9_col3, #T_ba5c3_row9_col4, #T_ba5c3_row9_col5, #T_ba5c3_row9_col6, #T_ba5c3_row10_col0, #T_ba5c3_row10_col1, #T_ba5c3_row10_col2, #T_ba5c3_row10_col3, #T_ba5c3_row10_col4, #T_ba5c3_row10_col5, #T_ba5c3_row10_col6, #T_ba5c3_row11_col0, #T_ba5c3_row11_col1, #T_ba5c3_row11_col2, #T_ba5c3_row11_col3, #T_ba5c3_row11_col4, #T_ba5c3_row11_col5, #T_ba5c3_row11_col6, #T_ba5c3_row12_col0, #T_ba5c3_row12_col1, #T_ba5c3_row12_col2, #T_ba5c3_row12_col3, #T_ba5c3_row12_col4, #T_ba5c3_row12_col5, #T_ba5c3_row12_col6, #T_ba5c3_row13_col0, #T_ba5c3_row13_col1, #T_ba5c3_row13_col2, #T_ba5c3_row13_col3, #T_ba5c3_row13_col4, #T_ba5c3_row13_col5, #T_ba5c3_row13_col6, #T_ba5c3_row14_col0, #T_ba5c3_row14_col2, #T_ba5c3_row14_col3, #T_ba5c3_row14_col4, #T_ba5c3_row14_col5, #T_ba5c3_row14_col6, #T_ba5c3_row15_col0, #T_ba5c3_row15_col1, #T_ba5c3_row15_col2, #T_ba5c3_row15_col3, #T_ba5c3_row15_col4, #T_ba5c3_row15_col5, #T_ba5c3_row16_col0, #T_ba5c3_row16_col1, #T_ba5c3_row16_col2, #T_ba5c3_row16_col3, #T_ba5c3_row16_col4, #T_ba5c3_row16_col5, #T_ba5c3_row16_col6, #T_ba5c3_row17_col0, #T_ba5c3_row17_col1, #T_ba5c3_row17_col2, #T_ba5c3_row17_col3, #T_ba5c3_row17_col4, #T_ba5c3_row17_col5, #T_ba5c3_row17_col6, #T_ba5c3_row18_col0, #T_ba5c3_row18_col1, #T_ba5c3_row18_col2, #T_ba5c3_row18_col3, #T_ba5c3_row18_col4, #T_ba5c3_row18_col5, #T_ba5c3_row18_col6, #T_ba5c3_row19_col0, #T_ba5c3_row19_col1, #T_ba5c3_row19_col2, #T_ba5c3_row19_col3, #T_ba5c3_row19_col4, #T_ba5c3_row19_col5, #T_ba5c3_row19_col6 {
#   text-align: left;
# }
# #T_ba5c3_row0_col2, #T_ba5c3_row0_col3, #T_ba5c3_row0_col4, #T_ba5c3_row0_col5, #T_ba5c3_row1_col5, #T_ba5c3_row14_col1, #T_ba5c3_row15_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ba5c3_row0_col7, #T_ba5c3_row1_col7, #T_ba5c3_row2_col7, #T_ba5c3_row3_col7, #T_ba5c3_row4_col7, #T_ba5c3_row5_col7, #T_ba5c3_row6_col7, #T_ba5c3_row7_col7, #T_ba5c3_row9_col7, #T_ba5c3_row10_col7, #T_ba5c3_row11_col7, #T_ba5c3_row12_col7, #T_ba5c3_row13_col7, #T_ba5c3_row14_col7, #T_ba5c3_row15_col7, #T_ba5c3_row16_col7, #T_ba5c3_row17_col7, #T_ba5c3_row18_col7, #T_ba5c3_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ba5c3_row8_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ba5c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba5c3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ba5c3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ba5c3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ba5c3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ba5c3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ba5c3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ba5c3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ba5c3_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba5c3_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_ba5c3_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ba5c3_row0_col1" class="data row0 col1" >0.0466</td>
#       <td id="T_ba5c3_row0_col2" class="data row0 col2" >0.0225</td>
#       <td id="T_ba5c3_row0_col3" class="data row0 col3" >0.1498</td>
#       <td id="T_ba5c3_row0_col4" class="data row0 col4" >0.1910</td>
#       <td id="T_ba5c3_row0_col5" class="data row0 col5" >0.1053</td>
#       <td id="T_ba5c3_row0_col6" class="data row0 col6" >0.7640</td>
#       <td id="T_ba5c3_row0_col7" class="data row0 col7" >0.3120</td>
#     </tr>
#     <tr>
#       <th id="T_ba5c3_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_ba5c3_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_ba5c3_row1_col1" class="data row1 col1" >0.0472</td>
#       <td id="T_ba5c3_row1_col2" class="data row1 col2" >0.0226</td>
#       <td id="T_ba5c3_row1_col3" class="data row1 col3" >0.1503</td>
#       <td id="T_ba5c3_row1_col4" class="data row1 col4" >0.1860</td>
#       <td id="T_ba5c3_row1_col5" class="data row1 col5" >0.1053</td>
#       <td id="T_ba5c3_row1_col6" class="data row1 col6" >0.7749</td>
#       <td id="T_ba5c3_row1_col7" class="data row1 col7" >1.0740</td>
#     </tr>
#     <tr>
#       <th id="T_ba5c3_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_ba5c3_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ba5c3_row2_col1" class="data row2 col1" >0.0477</td>
#       <td id="T_ba5c3_row2_col2" class="data row2 col2" >0.0234</td>
#       <td id="T_ba5c3_row2_col3" class="data row2 col3" >0.1528</td>
#       <td id="T_ba5c3_row2_col4" class="data row2 col4" >0.1595</td>
#       <td id="T_ba5c3_row2_col5" class="data row2 col5" >0.1061</td>
#       <td id="T_ba5c3_row2_col6" class="data row2 col6" >0.8270</td>
#       <td id="T_ba5c3_row2_col7" class="data row2 col7" >1.1480</td>
#     </tr>
#     <tr>
#       <th id="T_ba5c3_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_ba5c3_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ba5c3_row3_col1" class="data row3 col1" >0.0472</td>
#       <td id="T_ba5c3_row3_col2" class="data row3 col2" >0.0243</td>
#       <td id="T_ba5c3_row3_col3" class="data row3 col3" >0.1558</td>
#       <td id="T_ba5c3_row3_col4" class="data row3 col4" >0.1256</td>
#       <td id="T_ba5c3_row3_col5" class="data row3 col5" >0.1099</td>
#       <td id="T_ba5c3_row3_col6" class="data row3 col6" >0.7517</td>
#       <td id="T_ba5c3_row3_col7" class="data row3 col7" >4.1800</td>
#     </tr>
#     <tr>
#       <th id="T_ba5c3_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_ba5c3_row4_col0" class="data row4 col0" >K Neighbors Regressor</td>
#       <td id="T_ba5c3_row4_col1" class="data row4 col1" >0.0406</td>
#       <td id="T_ba5c3_row4_col2" class="data row4 col2" >0.0249</td>
#       <td id="T_ba5c3_row4_col3" class="data row4 col3" >0.1577</td>
#       <td id="T_ba5c3_row4_col4" class="data row4 col4" >0.1040</td>
#       <td id="T_ba5c3_row4_col5" class="data row4 col5" >0.1132</td>
#       <td id="T_ba5c3_row4_col6" class="data row4 col6" >0.7559</td>
#       <td id="T_ba5c3_row4_col7" class="data row4 col7" >0.5180</td>
#     </tr>
#     <tr>
#       <th id="T_ba5c3_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_ba5c3_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_ba5c3_row5_col1" class="data row5 col1" >0.0487</td>
#       <td id="T_ba5c3_row5_col2" class="data row5 col2" >0.0249</td>
#       <td id="T_ba5c3_row5_col3" class="data row5
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]

# %% [markdown]
# ## Analyze Model
# The plot_model function is used to analyze the performance of a trained model on the test set. It may require re-training the model in certain cases.

# %%
# plot residuals
plot_model(best, plot = 'residuals')

# %%
# plot error
plot_model(best, plot = 'error')

# %%
# plot feature importance
plot_model(best, plot = 'feature')

# %%
# Importacion de librerias
# Conexión a la base de datos
# ==========================================
import os
import sys
import pathlib

sys.path.append(
    os.path.join(pathlib.Path(os.getcwd()).parent)
)
from utils.bq_conn import bq_conn_file
# Tratamiento de datos
# ==========================================
import pandas as pd
import numpy as np
from datetime import datetime

# Graficas
# ==========================================
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import seaborn as sns

# Reparto de datos en train y test
# ==============================================================================
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.compose import make_column_selector

# Modelos ML
# ==========================================
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
from sklearn.model_selection import GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report


#from pycaret.clustering import *
#from pycaret.classification import *
#from pycaret.regression import *

# %% [markdown]
# ### Importo data

# %%
pd.options.display.max_columns = None

query = '''
SELECT
    *
FROM `Proyecto.DatosSecopI`
ORDER BY anno_cargue_secop DESC
'''
bq_client = bq_conn_file(project_id="dsa-miad-365616")
secop_I = bq_client.execute_query(query=query)
print(f"El número de filas del dataset: {secop_I.shape[0]}\nEl número de columnas del dataset: {secop_I.shape[1]}")
secop_I.head(5)
# Out:
# El número de filas del dataset: 26553
# El número de columnas del dataset: 38
#                    uid  anno_cargue_secop  id_modalidad  \
# 0   191389136418143424               2019            13
# 1  1912101041779226352               2019            12
# 2  1912101443259265538               2019            12
# 3   191294985788644918               2019            12
# 4   191988590538059861               2019            19
#
#      modalidad_de_contratacion estado_del_proceso  id_objeto_a_contratar  \
# 0  contratacion minima cuantia          celebrado               50000000
# 1  contratacion directa ley de          celebrado               53000000
# 2  contratacion directa ley de          celebrado               55000000
# 3  contratacion directa ley de          liquidado               72000000
# 4   asociacion publico privada          celebrado               73000000
#
#                       detalle_del_objeto_a_contratar  \
# 0  contratar servicio suministro elementos materi...
# 1  adquisicion uniformes para dotar personal cuer...
# 2  contratar diseno produccion tarjetas presentac...
# 3  prestar servicio mantenimiento preventivo corr...
# 4  desintegracion vehiculos automotores estado in...
#
#                 tipo_de_contrato municipio_de_obtencion municipios_ejecucion_  \
# 0                     suministro             facatativa            facatativa
# 1        prestacion de servicios                 bogota                bogota
# 2        prestacion de servicios                 bogota                bogota
# 3        prestacion de servicios                 bogota                bogota
# 4  no encontrado en hoja proceso                 bogota                bogota
#
#   departamento_ejecucion                       numero_de_proceso  \
# 0           cundinamarca                    CPMMSFFAMCNo01DE2019
# 1                 bogota  DIRGENERALCONTRATACIONDIRECTA184DE2019
# 2                 bogota  DIRGENERALCONTRATACIONDIRECTA188DE2019
# 3                 bogota  DIRGENERALCONTRATACIONDIRECTA106DE2019
# 4                 bogota           CONVENIODEASOCIACIÓN231DE2018
#
#      numero_de_contrato  cuantia_proceso id_grupo            nombre_grupo  \
# 0  CPMMSFFAMCNO01DE2019         50000000        E  productos de uso final
# 1             184DE2019      22980096902        E  productos de uso final
# 2             188DE2019         35998452        E  productos de uso final
# 3             106DE2019         16767536        F               servicios
# 4             231DE2018                0        F               servicios
#
#   id_familia                                     nombre_familia id_clase  \
# 0       5022                    productos de cereales legumbres   502213
# 1       5310                                               ropa   531027
# 2       5510                                    medios impresos   551015
# 3       7210  servicios de mantenimiento reparaciones de con...   721015
# 4       7318                   servicios de maquinado procesado   731810
#
#                               nombre_clase id_adjudicacion  \
# 0              harina productos de molinos         8143424
# 1                                uniformes         9226352
# 2                   publicaciones impresas         9265538
# 3  servicios de apoyo para la construccion         8644918
# 4                   servicios de maquinado         8059861
#
#   tipo_identifi_del_contratista identificacion_del_contratista  \
# 0       nit de persona juridica                      900791326
# 1       nit de persona juridica                      860020227
# 2       nit de persona juridica                      830001113
# 3       nit de persona juridica                      860025639
# 4       nit de persona juridica                      806011019
#
#                nom_razon_social_contratista tipo_doc_representante_legal  \
# 0                         inversiones ocazo         cedula de ciudadania
# 1       fondo rotatorio de la policia forpo      nit de persona juridica
# 2             imprenta nacional de colombia      nit de persona juridica
# 3  mitsubishi electric de colombia limitada      nit de persona juridica
# 4      recuperaciones naranjo recycling sas         cedula de ciudadania
#
#   identific_representante_legal  plazo_de_ejec_del_contrato_  \
# 0                    1022363447                          330
# 1                     860020227                          660
# 2                     830001113                           31
# 3                     860025639                          170
# 4                      57439563                          360
#
#    dias_ejec_final_contrato rango_de_ejec_del_contrato  prorrogado  \
# 0                       330                          D           0
# 1                       690                          D           1
# 2                        71                          D           1
# 3                       170                          D           0
# 4                       360                          D           0
#
#    tiempo_adiciones_en_dias  cuantia_contrato  con_adicion_pptal  \
# 0                         0          50000000                  0
# 1                        30       22980096902                  0
# 2                        40          35998452                  0
# 3                         0          16767536                  0
# 4                         0                 0                  0
#
#    valor_total_de_adiciones  valor_contrato_con_adiciones           moneda  \
# 0                         0                      50000000  peso colombiano
# 1                         0                   22980096902  peso colombiano
# 2                         0                      35998452  peso colombiano
# 3                         0                      16767536  peso colombiano
# 4                         0                             0  peso colombiano
#
#                             objeto_del_contrato_a_la  \
# 0  contratar compra elementos materia prima para ...
# 1  adquisicion uniformes para dotar personal cuer...
# 2  contratar diseno produccion tarjetas presentac...
# 3  prestar servicio mantenimiento preventivo corr...
# 4  desintegracion vehiculos automotores estado in...
#
#                              ruta_proceso_en_secop_i
# 0  {'url': 'https://www.contratos.gov.co/consulta...
# 1  {'url': 'https://www.contratos.gov.co/consulta...
# 2  {'url': 'https://www.contratos.gov.co/consulta...
# 3  {'url': 'https://www.contratos.gov.co/consulta...
# 4  {'url': 'https://www.contratos.gov.co/consulta...

# %%
secopI_filter = secop_I.filter(items=['id_modalidad','estado_del_proceso','id_objeto_a_contratar','tipo_de_contrato',
                                      'departamento_ejecucion', 'numero_de_proceso','cuantia_proceso','id_grupo',
                                      'id_familia','id_clase','prorrogado','plazo_de_ejec_del_contrato_'
                                      ])
secopI_filter.head(5)
# Out:
#    id_modalidad estado_del_proceso  id_objeto_a_contratar  \
# 0            13          celebrado               50000000
# 1            12          celebrado               53000000
# 2            12          celebrado               55000000
# 3            12          liquidado               72000000
# 4            19          celebrado               73000000
#
#                 tipo_de_contrato departamento_ejecucion  \
# 0                     suministro           cundinamarca
# 1        prestacion de servicios                 bogota
# 2        prestacion de servicios                 bogota
# 3        prestacion de servicios                 bogota
# 4  no encontrado en hoja proceso                 bogota
#
#                         numero_de_proceso  cuantia_proceso id_grupo  \
# 0                    CPMMSFFAMCNo01DE2019         50000000        E
# 1  DIRGENERALCONTRATACIONDIRECTA184DE2019      22980096902        E
# 2  DIRGENERALCONTRATACIONDIRECTA188DE2019         35998452        E
# 3  DIRGENERALCONTRATACIONDIRECTA106DE2019         16767536        F
# 4           CONVENIODEASOCIACIÓN231DE2018                0        F
#
#   id_familia id_clase  prorrogado  plazo_de_ejec_del_contrato_
# 0       5022   502213           0                          330
# 1       5310   531027           1                          660
# 2       5510   551015           1                           31
# 3       7210   721015           0                          170
# 4       7318   731810           0                          360

# %% [markdown]
# ### Clases a clasificar

# %%
secopI_filter['prorrogado'].value_counts()
# Out:
# 0    25823
# 1      730
# Name: prorrogado, dtype: Int64

# %% [markdown]
# ### División train y test

# %%
X_train, X_test, y_train, y_test = train_test_split(
                                        secopI_filter.drop('prorrogado', axis = 1),
                                        secopI_filter['prorrogado'],
                                        train_size   = 0.9,
                                        random_state = 1234,
                                        shuffle      = True
                                    )

# %% [markdown]
# ### Preprocesamiento - Pipeline y ColumnTransformer
#
#
# Las clases `ColumnTransformer` y `make_column_transformer` del módulo sklearn.compose permiten combinar múltiples transformaciones de preprocesado, especificando a qué columnas se aplica cada una. Como todo transformer, tiene un método de entrenamiento (fit) y otro de transformación (transform) . Esto permite que el aprendizaje de las transformaciones se haga únicamente con observaciones de entrenamiento, y se puedan aplicar después a cualquier conjunto de datos. La idea detrás de este módulo es la siguiente:
#
# Definir todas las transformaciones (escalado, selección, filtrado...) que se desea aplicar y a qué columnas `ColumnTransformer()`. La selección de columnas puede hacerse por: nombre. índice, máscara booleana, slice, patrón regex, por tipo de columna o con las funciones de selección make_column_selector.
#
# Aprender los parámetros necesarios para dichas transformaciones con las observaciones de entrenamiento `.fit()`.
#
# Aplicar las transformaciones aprendidas a cualquier conjunto de datos `.transform()`.

# %%
numeric_cols = X_train.select_dtypes(include=['float64', 'int']).columns.to_list()
cat_cols = X_train.select_dtypes(include=['object', 'category']).columns.to_list()

# Transformaciones para las variables numéricas
numeric_transformer = Pipeline(
                        steps=[
                            ('imputer', SimpleImputer(strategy='median')),
                            ('scaler', StandardScaler())
                        ]
                      )


# Transformaciones para las variables categóricas
categorical_transformer = Pipeline(
                            steps=[
                                ('imputer', SimpleImputer(strategy='most_frequent')),
                                ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
                            ]
                          )

preprocessor = ColumnTransformer(
                    transformers=[
                        ('numeric', numeric_transformer, numeric_cols),
                        ('cat', categorical_transformer, cat_cols)
                    ],
                    remainder='passthrough',
                    verbose_feature_names_out = False
               ).set_output(transform="pandas")

X_train_prep = preprocessor.fit_transform(X_train)
X_test_prep  = preprocessor.transform(X_test)

# %%
encoded_cat = preprocessor.named_transformers_['cat'].named_steps['onehot'].get_feature_names_out(input_features=cat_cols)
labels = np.concatenate([numeric_cols, encoded_cat])

# %% [markdown]
# ### Modelo

# %%
# Creación del modelo
# ------------------------------------------------------------------------------
modelo = DecisionTreeClassifier(
            max_depth         = 5,
            criterion         = 'gini',
            random_state      = 123
          )

# Entrenamiento del modelo
# ------------------------------------------------------------------------------
modelo.fit(X_train_prep, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=123)

# %%
# Estructura del árbol creado
# ------------------------------------------------------------------------------
fig, ax = plt.subplots(figsize=(13, 6))

print(f"Profundidad del árbol: {modelo.get_depth()}")
print(f"Número de nodos terminales: {modelo.get_n_leaves()}")

plot = plot_tree(
            decision_tree = modelo,
            feature_names = labels.tolist(),
            class_names   = 'ventas_altas',
            filled        = True,
            impurity      = False,
            fontsize      = 7,
            ax            = ax
       )
# Out:
# Profundidad del árbol: 5
# Número de nodos terminales: 19

# %% [markdown]
# ### Podado del árbol (pruning)
#
#
# Aunque inicialmente se ha empleado un valor de max_depth=5, este no tiene por qué ser el mejor valor. Con el objetivo de identificar la profundidad óptima que consigue reducir la varianza y aumentar la capacidad predictiva del modelo, se somete al árbol a un proceso de pruning.

# %%
# Post pruning (const complexity pruning) por validación cruzada
# ------------------------------------------------------------------------------
# Valores de ccp_alpha evaluados
param_grid = {'ccp_alpha':np.linspace(0, 5, 10)}

# Búsqueda por validación cruzada
grid = GridSearchCV(
        # El árbol se crece al máximo posible antes de aplicar el pruning
        estimator = DecisionTreeClassifier(
                            max_depth         = None,
                            min_samples_split = 2,
                            min_samples_leaf  = 1,
                            random_state      = 123
                       ),
        param_grid = param_grid,
        scoring    = 'accuracy',
        cv         = 10,
        refit      = True,
        return_train_score = True
      )

grid.fit(X_train_prep, y_train)

fig, ax = plt.subplots(figsize=(6, 3.84))
scores = pd.DataFrame(grid.cv_results_)
scores.plot(x='param_ccp_alpha', y='mean_train_score', yerr='std_train_score', ax=ax)
scores.plot(x='param_ccp_alpha', y='mean_test_score', yerr='std_test_score', ax=ax)
ax.set_title("Error de validacion cruzada vs hiperparámetro ccp_alpha");
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/cy/6g84nnc90d3blx29rvlncq2c0000gn/T/ipykernel_41662/1025390184.py in <cell line: 22>()
#      20       )
#      21
# ---> 22 grid.fit(X_train_prep, y_train)
#      23
#      24 fig, ax = plt.subplots(figsize=(6, 3.84))
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1086                 self._iterating = self._original_iterator is not None
#    1087
# -> 1088             while self.dispatch_one_batch(iterator):
#    1089                 pass
#    1090
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     899                 return False
#     900             else:
# --> 901                 self._dispatch(tasks)
#     902                 return True
#     903
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     817         with self._lock:
#     818             job_idx = len(self._jobs)
# --> 819             job = self._backend.apply_async(batch, callback=cb)
#     820             # A job can complete so quickly than its callback is
#     821             # called before we get here, causing self._jobs to
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     595         # Don't delay the application, to avoid keeping the input
#     596         # arguments in memory
# --> 597         self.results = batch()
#     598
#     599     def get(self):
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/joblib/parallel.py in __call__(self)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/joblib/parallel.py in <listcomp>(.0)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684             estimator.fit(X_train, **fit_params)
#     685         else:
# --> 686             estimator.fit(X_train, y_train, **fit_params)
#     687
#     688     except Exception:
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     887         """
#     888
# --> 889         super().fit(
#     890             X,
#     891             y,
#
# ~/miniconda3/envs/proyecto/lib/python3.10/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     377             )
#     378
# --> 379         builder.build(self.tree_, X, y, sample_weight)
#     380
#     381         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
# Mejor valor ccp_alpha encontrado
# ------------------------------------------------------------------------------
grid.best_params_
# Out:
# {'ccp_alpha': 0.0}

# %% [markdown]
# Una vez identificado el valor óptimo de `ccp_alpha`, se reentrena el árbol indicando este valor en sus argumentos. Si en el `GridSearchCV()` se indica `refit=True`, este reentrenamiento se hace automáticamente y el modelo resultante se encuentra almacenado en .best_estimator_.

# %%
# Estructura del árbol final
# ------------------------------------------------------------------------------
modelo_final = grid.best_estimator_
print(f"Profundidad del árbol: {modelo_final.get_depth()}")
print(f"Número de nodos terminales: {modelo_final.get_n_leaves()}")
# Out:
# Profundidad del árbol: 1
# Número de nodos terminales: 2

# %%
# Error de test del modelo final
#-------------------------------------------------------------------------------
predicciones = modelo_final.predict(X = X_test_prep)
# Calcula la matriz de confusión
#definimos funciona para mostrar los resultados
def mostrar_resultados(y_test, pred_y):
    conf_matrix = confusion_matrix(y_test, pred_y)
    plt.figure(figsize=(5, 5))
    sns.heatmap(conf_matrix, annot=True, fmt="d");
    plt.title("Confusion matrix")
    plt.ylabel('Real')
    plt.xlabel('Predicho')
    plt.show()
    print (classification_report(y_test, pred_y))
mostrar_resultados(y_test, predicciones)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      2593
#          1.0       1.00      1.00      1.00        63
#
#     accuracy                           1.00      2656
#    macro avg       1.00      1.00      1.00      2656
# weighted avg       1.00      1.00      1.00      2656

# %% [markdown]
# ## Importancia de predictores
#
#
# La importancia de cada predictor en modelo se calcula como la reducción total (normalizada) en el criterio de división, en este caso el índice Gini, que consigue el predictor en las divisiones en las que participa. Si un predictor no ha sido seleccionado en ninguna divisón, no se ha incluido en el modelo y por lo tanto su importancia es 0.

# %%
print("Importancia de los predictores en el modelo")
print("-------------------------------------------")
importancia_predictores = pd.DataFrame(
                            {'predictor': labels.tolist(),
                             'importancia': modelo_final.feature_importances_}
                            )
importancia_predictores.sort_values('importancia', ascending=False)
# Out:
# Importancia de los predictores en el modelo
# -------------------------------------------
#                                                predictor  importancia
# 3                               tiempo_adiciones_en_dias          1.0
# 0                                           id_modalidad          0.0
# 12699  numero_de_proceso_DIRGRALCONVENIODEINTEGRACION...          0.0
# 12706  numero_de_proceso_DIRGRALCONVENIODEINTEGRACION...          0.0
# 12705  numero_de_proceso_DIRGRALCONVENIODEINTEGRACION...          0.0
# ...                                                  ...          ...
# 6351                        numero_de_proceso_2410222017          0.0
# 6350                        numero_de_proceso_2410212016          0.0
# 6349                        numero_de_proceso_2410212015          0.0
# 6348                        numero_de_proceso_2410202017          0.0
# 19052                                       id_clase_N/D          0.0
#
# [19053 rows x 2 columns]
